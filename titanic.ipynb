# %%
import pandas as pd
import numpy as np

titanic_df = pd.read_csv("titanic.csv")
titanic_df
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     NaN       NaN                                              NaN
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic_df.isna().sum()
# Out:
# pclass          1
# survived        1
# name            1
# sex             1
# age           264
# sibsp           1
# parch           1
# ticket          1
# fare            2
# cabin        1015
# embarked        3
# boat          824
# body         1189
# home.dest     565
# dtype: int64

# %%
titanic_df.drop(["cabin", "boat", "body", "home.dest"], inplace=True, axis=1)
titanic_df.isna().sum()
# Out:
# pclass        1
# survived      1
# name          1
# sex           1
# age         264
# sibsp         1
# parch         1
# ticket        1
# fare          2
# embarked      3
# dtype: int64

# %%
titanic_df['age'] = titanic_df['age'].fillna(titanic_df['age'].median())
titanic_df.isna().sum()
# Out:
# pclass      1
# survived    1
# name        1
# sex         1
# age         0
# sibsp       1
# parch       1
# ticket      1
# fare        2
# embarked    3
# dtype: int64

# %%
titanic_df = titanic_df.dropna().reset_index(drop=True)
titanic_df.isna().sum()
# Out:
# pclass      0
# survived    0
# name        0
# sex         0
# age         0
# sibsp       0
# parch       0
# ticket      0
# fare        0
# embarked    0
# dtype: int64

# %%
titanic_df
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1301     3.0       0.0                             Zabour, Miss. Hileni
# 1302     3.0       0.0                            Zabour, Miss. Thamine
# 1303     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1304     3.0       0.0                              Zakarian, Mr. Ortin
# 1305     3.0       0.0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare embarked
# ...

# %%
titanic_df.describe()
# Out:
#             pclass     survived          age       sibsp        parch  \
# count  1306.000000  1306.000000  1306.000000  1306.00000  1306.000000
# mean      2.296325     0.381317    29.448060     0.50000     0.385911
# std       0.837037     0.485896    12.857854     1.04258     0.866357
# min       1.000000     0.000000     0.166700     0.00000     0.000000
# 25%       2.000000     0.000000    22.000000     0.00000     0.000000
# 50%       3.000000     0.000000    28.000000     0.00000     0.000000
# 75%       3.000000     1.000000    35.000000     1.00000     0.000000
# max       3.000000     1.000000    80.000000     8.00000     9.000000
#
#               fare
# count  1306.000000
# mean     33.223956
# std      51.765986
# min       0.000000
# 25%       7.895800
# 50%      14.454200
# 75%      31.275000
# max     512.329200

# %%
def remove_outliers(df,columns,n_std):
    for col in columns:
        print('Working on column: {}'.format(col))
        
        mean = df[col].mean()
        sd = df[col].std()

        df = df[(df[col] <= mean+(n_std*sd))]
        
        
    return df

# %%
titanic_dfc = remove_outliers(titanic_df, ["age", "sibsp", "parch", "fare"], 3)
titanic_dfc
# Out:
# Working on column: age
# Working on column: sibsp
# Working on column: parch
# Working on column: fare
#       pclass  survived                                             name  \
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5        1.0       1.0                              Anderson, Mr. Harry
# ...      ...       ...                                              ...
# 1301     3.0       0.0                             Zabour, Miss. Hileni
# 1302     3.0       0.0                            Zabour, Miss. Thamine
# 1303     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1304     3.0       0.0                              Zakarian, Mr. Ortin
# 1305     3.0       0.0                               Zimmerman, Mr. Leo
#
# ...

# %%
diff_df = titanic_df[~titanic_df.isin(titanic_dfc)].dropna()
diff_df
# Out:
#       pclass  survived                                               name  \
# 0        1.0       1.0                      Allen, Miss. Elisabeth Walton
# 9        1.0       0.0                            Artagaveytia, Mr. Ramon
# 10       1.0       0.0                             Astor, Col. John Jacob
# 11       1.0       1.0  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 14       1.0       1.0               Barkworth, Mr. Algernon Henry Wilson
# ...      ...       ...                                                ...
# 1177     3.0       0.0                              Sage, Mr. John George
# 1178     3.0       0.0                     Sage, Mrs. John (Annie Bullen)
# 1208     3.0       0.0                                 Skoog, Mr. Wilhelm
# 1209     3.0       0.0    Skoog, Mrs. William (Anna Bernhardina Karlsson)
# 1232     3.0       0.0                                Svensson, Mr. Johan
#
#          sex   age  sibsp  parch    ticket      fare embarked
# ...

# %%
print("Clean columns stats : \n")
titanic_dfc_stat = titanic_dfc.describe()
print(titanic_dfc_stat.iloc[1:2 , [3, 4, 5]])

print("\n\n\n\n")

print("Removed columns stats : \n")
diff_df_stat = diff_df.describe()
print(diff_df_stat.iloc[1:2 , [3, 4, 5]])
# Out:
# Clean columns stats :
#
#          sibsp     parch       fare
# mean  0.346633  0.254364  25.509389
#
#
#
#
#
# Removed columns stats :
#
#          sibsp    parch        fare
# mean  2.291262  1.92233  123.327106

# %%
from sklearn.preprocessing import LabelEncoder

# Instantiate a LabelEncoder object
le = LabelEncoder()

# %%
titanic_dfc['sex_encoded'] = le.fit_transform(titanic_dfc['sex'])
titanic_dfc['embarked_encoded'] = le.fit_transform(titanic_dfc['embarked'])
titanic_dfc = titanic_dfc.reset_index(drop=True)
titanic_dfc['Family'] = titanic_dfc.parch + titanic_dfc.sibsp

titanic_dfc
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                   Allison, Master. Hudson Trevor
# 1        1.0       0.0                     Allison, Miss. Helen Loraine
# 2        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 3        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 4        1.0       1.0                              Anderson, Mr. Harry
# ...      ...       ...                                              ...
# 1198     3.0       0.0                             Zabour, Miss. Hileni
# 1199     3.0       0.0                            Zabour, Miss. Thamine
# 1200     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1201     3.0       0.0                              Zakarian, Mr. Ortin
# 1202     3.0       0.0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare embarked  sex_encoded  \
# ...

# %%
titanic_dfc["Title"] = titanic_dfc.name.apply(lambda name: name.split(",")[1].split(".")[0])
titanic_dfc
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                   Allison, Master. Hudson Trevor
# 1        1.0       0.0                     Allison, Miss. Helen Loraine
# 2        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 3        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 4        1.0       1.0                              Anderson, Mr. Harry
# ...      ...       ...                                              ...
# 1198     3.0       0.0                             Zabour, Miss. Hileni
# 1199     3.0       0.0                            Zabour, Miss. Thamine
# 1200     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1201     3.0       0.0                              Zakarian, Mr. Ortin
# 1202     3.0       0.0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare embarked  sex_encoded  \
# ...

# %%
titanic_dfc["Title"].unique()
# Out:
# array([' Master', ' Miss', ' Mr', ' Mrs', ' Mme', ' Dr', ' Major',
#        ' Lady', ' Sir', ' Col', ' Mlle', ' Dona', ' Jonkheer',
#        ' the Countess', ' Don', ' Rev', ' Ms'], dtype=object)

# %%
titanic_dfc['title_encoded'] = le.fit_transform(titanic_dfc['Title'])

# %%
titanic_dfc.drop(["name", "sex", "embarked", "Title"], axis = 1, inplace = True)
titanic_dfc
# Out:
#       pclass  survived      age  sibsp  parch  ticket      fare  sex_encoded  \
# 0        1.0       1.0   0.9167    1.0    2.0  113781  151.5500            1
# 1        1.0       0.0   2.0000    1.0    2.0  113781  151.5500            0
# 2        1.0       0.0  30.0000    1.0    2.0  113781  151.5500            1
# 3        1.0       0.0  25.0000    1.0    2.0  113781  151.5500            0
# 4        1.0       1.0  48.0000    0.0    0.0   19952   26.5500            1
# ...      ...       ...      ...    ...    ...     ...       ...          ...
# 1198     3.0       0.0  14.5000    1.0    0.0    2665   14.4542            0
# 1199     3.0       0.0  28.0000    1.0    0.0    2665   14.4542            0
# 1200     3.0       0.0  26.5000    0.0    0.0    2656    7.2250            1
# 1201     3.0       0.0  27.0000    0.0    0.0    2670    7.2250            1
# 1202     3.0       0.0  29.0000    0.0    0.0  315082    7.8750            1
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set (rc = {'figure.figsize':(19, 9)})
sns.heatmap(titanic_dfc.corr(), cmap = "YlOrBr", annot=True);
plt.show ()

# %%
titanic_dfc.corr().iloc[:, 1].abs().sort_values(ascending=False)
# Out:
# survived            1.000000
# sex_encoded         0.532232
# fare                0.294747
# pclass              0.286009
# parch               0.216198
# title_encoded       0.206418
# Family              0.191213
# embarked_encoded    0.162327
# sibsp               0.095196
# age                 0.071123
# Name: survived, dtype: float64

# %%
titanic_dfc["age_category"] = pd.cut(titanic_dfc["age"], bins=[0, 12, 18, 55, 80], labels=["Enfant", "Adolescent", "Adulte", "Senior"])
titanic_dfc
# Out:
#       pclass  survived      age  sibsp  parch  ticket      fare  sex_encoded  \
# 0        1.0       1.0   0.9167    1.0    2.0  113781  151.5500            1
# 1        1.0       0.0   2.0000    1.0    2.0  113781  151.5500            0
# 2        1.0       0.0  30.0000    1.0    2.0  113781  151.5500            1
# 3        1.0       0.0  25.0000    1.0    2.0  113781  151.5500            0
# 4        1.0       1.0  48.0000    0.0    0.0   19952   26.5500            1
# ...      ...       ...      ...    ...    ...     ...       ...          ...
# 1198     3.0       0.0  14.5000    1.0    0.0    2665   14.4542            0
# 1199     3.0       0.0  28.0000    1.0    0.0    2665   14.4542            0
# 1200     3.0       0.0  26.5000    0.0    0.0    2656    7.2250            1
# 1201     3.0       0.0  27.0000    0.0    0.0    2670    7.2250            1
# 1202     3.0       0.0  29.0000    0.0    0.0  315082    7.8750            1
#
# ...

# %%
titanic_dfc['age_range'] = le.fit_transform(titanic_dfc['age_category'])
titanic_dfc.drop(["age_category"], axis = 1, inplace = True)
titanic_dfc
# Out:
#       pclass  survived      age  sibsp  parch  ticket      fare  sex_encoded  \
# 0        1.0       1.0   0.9167    1.0    2.0  113781  151.5500            1
# 1        1.0       0.0   2.0000    1.0    2.0  113781  151.5500            0
# 2        1.0       0.0  30.0000    1.0    2.0  113781  151.5500            1
# 3        1.0       0.0  25.0000    1.0    2.0  113781  151.5500            0
# 4        1.0       1.0  48.0000    0.0    0.0   19952   26.5500            1
# ...      ...       ...      ...    ...    ...     ...       ...          ...
# 1198     3.0       0.0  14.5000    1.0    0.0    2665   14.4542            0
# 1199     3.0       0.0  28.0000    1.0    0.0    2665   14.4542            0
# 1200     3.0       0.0  26.5000    0.0    0.0    2656    7.2250            1
# 1201     3.0       0.0  27.0000    0.0    0.0    2670    7.2250            1
# 1202     3.0       0.0  29.0000    0.0    0.0  315082    7.8750            1
#
# ...
